# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayashree190/AI/blob/master/facerecognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
image_path = 'j.jpg'
im = cv2.imread(image_path)
plt.imshow(im)
plt.show()
faces,confidences = cv.detect_face(im)
for face in faces:
  (startX,startY) = face[0],face[1]
  (endX,endY) = face[2],face[3]
  cv2.rectangle(im, (startX,startY),(endX,endY),(0,255,0),2)
  plt.imshow(im)
  plt.show()

# %%
# !pip3 install cvlib
# Out:
# ...
#      |████████████████████████████████| 10.0MB 2.6MB/s
# ...
#   Created wheel for cvlib: filename=cvlib-0.2.3-cp36-none-any.whl size=10043491 sha256=8dc03cd910b027ce4b86d539cfa344f518b7d914dd1f600bba210bf4e6456327
#   Stored in directory: /root/.cache/pip/wheels/c9/83/ca/701a48deacbc78758f33173252feb97297316c40af783264e2
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-cp36-none-any.whl size=12073 sha256=c5d3615471b39cd06f59f7817f3947da167d79c9d5f02c7ca95032a8bb34a451
#   Stored in directory: /root/.cache/pip/wheels/c0/e9/6b/ea01090205e285175842339aa3b491adeb4015206cda272ff0
# Successfully built cvlib progressbar
# ...
